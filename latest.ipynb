# %%
import pandas as pd

# %%
df = pd.read_json("data/radar_data.json")

# %%
df
# Out:
#                   generated_at  count  \
# 0    2026-04-08 05:01:10+00:00   2035
# 1    2026-04-08 05:01:10+00:00   2035
# 2    2026-04-08 05:01:10+00:00   2035
# 3    2026-04-08 05:01:10+00:00   2035
# 4    2026-04-08 05:01:10+00:00   2035
# ...                        ...    ...
# 2030 2026-04-08 05:01:10+00:00   2035
# 2031 2026-04-08 05:01:10+00:00   2035
# 2032 2026-04-08 05:01:10+00:00   2035
# 2033 2026-04-08 05:01:10+00:00   2035
# 2034 2026-04-08 05:01:10+00:00   2035
#
#                                                   items
# 0     {'cve_id': 'CVE-2026-0005', 'description': 'In...
# 1     {'cve_id': 'CVE-2026-0006', 'description': 'In...
# 2     {'cve_id': 'CVE-2026-0007', 'description': 'In...
# 3     {'cve_id': 'CVE-2026-0008', 'description': 'In...
# 4     {'cve_id': 'CVE-2026-0010', 'description': 'In...
# ...                                                 ...
# 2030  {'cve_id': 'CVE-2026-5733', 'description': 'In...
# ...

# %%
df.head()
# Out:
#                generated_at  count  \
# 0 2026-04-08 05:01:10+00:00   2035
# 1 2026-04-08 05:01:10+00:00   2035
# 2 2026-04-08 05:01:10+00:00   2035
# 3 2026-04-08 05:01:10+00:00   2035
# 4 2026-04-08 05:01:10+00:00   2035
#
#                                                items
# 0  {'cve_id': 'CVE-2026-0005', 'description': 'In...
# 1  {'cve_id': 'CVE-2026-0006', 'description': 'In...
# 2  {'cve_id': 'CVE-2026-0007', 'description': 'In...
# 3  {'cve_id': 'CVE-2026-0008', 'description': 'In...
# 4  {'cve_id': 'CVE-2026-0010', 'description': 'In...
